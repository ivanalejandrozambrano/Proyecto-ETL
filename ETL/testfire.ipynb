# %%
import firebase_admin
from firebase_admin import credentials

cred = credentials.Certificate("modelado-810a4-firebase-adminsdk-n75i9-3d6007cd51.json")
firebase_admin.initialize_app(cred)

# %%
pip install firebase_admin
# Out:
# ...
#                                               0.0/119.9 kB ? eta -:--:--
#      -----------------------------           92.2/119.9 kB 2.6 MB/s eta 0:00:01
#      -------------------------------------- 119.9/119.9 kB 2.3 MB/s eta 0:00:00
# ...
#                                               0.0/11.4 MB ? eta -:--:--
#                                               0.2/11.4 MB 7.0 MB/s eta 0:00:02
#      -                                        0.5/11.4 MB 6.4 MB/s eta 0:00:02
#      ---                                      1.0/11.4 MB 7.5 MB/s eta 0:00:02
#      ----                                     1.4/11.4 MB 8.0 MB/s eta 0:00:02
#      ------                                   1.8/11.4 MB 8.2 MB/s eta 0:00:02
#      --------                                 2.3/11.4 MB 8.6 MB/s eta 0:00:02
#      --------                                 2.5/11.4 MB 8.0 MB/s eta 0:00:02
#      ----------                               2.8/11.4 MB 7.9 MB/s eta 0:00:02
# ...

# %%
from pymongo import MongoClient
from bson import json_util
import requests
import json
from bson.objectid import ObjectId
client = MongoClient("mongodb://localhost:27016")
db = client.origen  # Nombre de la base de datos
collection = db.test  # Nombre de la colección
# Obtener los primeros 5 documentos
data = list(collection.find({"actualizado_en": 1}).limit(2))
serialized_data = json_util.dumps(data)

# %%
import requests
import json
from datetime import datetime


# URL de la API que deseas llamar
url = "http://localhost:5000/api/data"

# Realiza la solicitud GET a la API
response = requests.get(url)

# Verifica el código de estado de la respuesta
if response.status_code == 200:
    # La solicitud fue exitosa
    data = response.json()  # Obtiene los datos de la respuesta en formato JSON

    for datau in data:        

        datau['seguir'] = datau["_id"]["$oid"]

        datau.pop("_id", None)

    keys = datau.keys()
    print(datau['seguir'])
    """ print(type(data))
    print(type(response))
    print(keys)
    print(data) """
    jdata = json.dumps(data)
    print(jdata)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File c:\Users\ivanz\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# ...

# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import db


cred = credentials.Certificate('modelado-810a4-firebase-adminsdk-n75i9-3d6007cd51.json')
firebase_admin.initialize_app(cred, {
    'databaseURL': '**********************'
})

# Obtén una referencia a la ubicación donde deseas insertar los datos
ref = db.reference('mongo')

# Inserta los datos utilizando push() o set()
ref.push().set(jdata)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 5
#       2 from firebase_admin import db
#       4 # Get a database reference to our blog.
# ----> 5 ref = db.reference('https://modelado-810a4-default-rtdb.firebaseio.com/')
#       7 ref.push().set(serialized_data)
#
# File c:\Users\ivanz\AppData\Local\Programs\Python\Python311\Lib\site-packages\firebase_admin\db.py:69, in reference(path, app, url)
#      49 """Returns a database ``Reference`` representing the node at the specified path.
#      50
#      51 If no path is specified, this function returns a ``Reference`` that represents the database
#    (...)
#      66   ValueError: If the specified path or app is invalid.
#      67 """
#      68 service = _utils.get_app_service(app, _DB_ATTRIBUTE, _DatabaseService)
# ---> 69 client = service.get_client(url)
#      70 return Reference(client=client, path=path)
# ...
